# %%
import pandas as pd

# %%
average_number = pd.read_csv('../../TABLAS LATEX/languages.csv', sep=';', decimal=',')
average_number = average_number[['Language', 'Average']]
average_number
# Out:
#       Language  Average
# 0      English  5607.00
# 1      Spanish  2348.33
# 2       French   832.33
# 3      Chinese   770.00
# 4      Italian   579.00
# 5      Russian   560.33
# 6   Portuguese   462.67
# 7       Arabic   418.67
# 8     Japanese   410.33
# 9       German   388.67
# 10      Korean   175.00
# 11     Turkish   151.33
# 12      Polish    87.00
# 13       Hindi    78.00
# 14       Dutch    73.67
# 15   Ukrainian    71.33
# 16       Greek    67.33
# 17     Serbian    63.00
# 18     Tagalog    59.67
# 19  Indonesian    58.67
# 20     Persian    54.33
# 21        Thai    51.67
# 22  Vietnamese    49.67
# 23      Hebrew    46.67
# 24        Urdu    39.67
# 25   Hungarian    33.33
# 26     Swedish    30.67
# 27       Czech    25.00
# 28    Romanian    23.67
# 29     Catalan    23.33
# 30    Croatian    22.33
# 31     Punjabi    18.00
# 32       Tamil    14.67
# 33     Bengali    12.67
# 34       Latin    12.33
# 35      Danish    12.00
# 36   Bulgarian    11.67
# 37      Slovak    11.00
# 38   Norwegian    10.33
# 39     Finnish     6.33
# 40      Gaelic     2.67
# 41   Icelandic     2.33

# %% [markdown]
# # Preply

# %%
preply = pd.read_csv('../data/results/final_dataframes/preply.csv', index_col=0)
preply = preply.drop_duplicates(subset=['user_name', 'language'])

# %%
preply.head()

# %%
preply.columns
# Out:
# Index(['language', 'position', 'retrieval_date', 'is_featured', 'user_name',
#        'url', 'nationality_full', 'avg_rating', 'num_ratings', 'teaches',
#        'subjects', 'speaks', 'lessons', 'price', 'price_currency',
#        'avatar_url', 'nationality', 'clean_name', 'sanitized_name', 'gender',
#        'probability', 'count', 'first_name', 'probability_male',
#        'probability_female', 'gender_tuned', 'income_level', 'Code'],
#       dtype='object')

# %%
from scipy.stats import ks_2samp
import numpy as np

def hypothesis_test(group1, group2, alpha=0.1):
    st, p_value = ks_2samp(group1, group2)
    if p_value<alpha:
        return st, p_value
    else:
        return st, p_value
    
def compute_aggregated_feature_top_k(df, top_k, language_col, aggregation_col, target_cols, group1, group2):
    count_group1 = 'count_{}'.format(group1)
    count_group2 = 'count_{}'.format(group2)
    variance_group1 = 'variance_{}'.format(group1)
    variance_group2 = 'variance_{}'.format(group2)
    mean_group1 = 'mean_{}'.format(group1)
    mean_group2 = 'mean_{}'.format(group2)
    median_group1 = 'median_{}'.format(group1)
    median_group2 = 'median_{}'.format(group2)
    
    results = pd.DataFrame(columns=['language', 'top_k', 'target_col', 'aggregation_col', mean_group1, mean_group2, median_group1, median_group2, count_group1, count_group2, variance_group1, variance_group2, 'statistic', 'p_value'])
    
    for lang in df[language_col].unique():
        temp = df[df[language_col]==lang]
        temp = temp.sort_values(by='position', ascending=True)
        
        for target in target_cols:
            temp = temp.dropna(subset=[target])
            temp[target] = pd.to_numeric(temp[target], errors='coerce')
            if top_k is not None:
                temp = temp.head(top_k)
        
            g1 = temp[temp[aggregation_col]==group1][target].values
            g2 = temp[temp[aggregation_col]==group2][target].values
            
            g1_count = len(g1)
            g2_count = len(g2)

            g1_mean = np.nanmean(g1) if g1_count else None
            g2_mean = np.nanmean(g2) if g2_count else None
            
            g1_median = np.nanmedian(g1) if g1_count else None
            g2_median = np.nanmedian(g2) if g2_count else None
            
            g1_var = g1.var() if g1_count else None
            g2_var = g2.var() if g2_count else None
            
            #Hypothesis testing
            if len(g1)>0 and len(g2)>0:
                st, p_value = hypothesis_test(g1, g2)
            else:
                st, p_value = None, None
            
            results = results.append({'language': lang, 'top_k': len(temp), 'target_col': target, 'aggregation_col': aggregation_col,
                                      mean_group1: g1_mean, mean_group2: g2_mean, median_group1: g1_median, median_group2: g2_median, count_group1: g1_count, count_group2: g2_count,
                                      variance_group1: g1_var, variance_group2: g2_var, 'statistic': st, 'p_value': p_value}, ignore_index=True)

    return results

# %%
preply_results_40 = compute_aggregated_feature_top_k(preply, 40, 'language', 'gender_tuned', ['price', 'avg_rating', 'num_ratings'], 'male', 'female')

# %%
preply_results_all = compute_aggregated_feature_top_k(preply, None, 'language', 'gender_tuned', ['price', 'avg_rating', 'num_ratings'], 'male', 'female')

# %%
preply_results = pd.concat([preply_results_40, preply_results_all])

# %%
preply_results = pd.merge(preply_results, average_number, how='left', left_on='language', right_on='Language')
preply_results = preply_results.rename(columns={'Average': 'average_num_teachers'})

# %%
preply_results.head()
# Out:
#   language top_k   target_col aggregation_col  mean_male  mean_female  \
# 0     Thai    40        price    gender_tuned  12.250000    13.472222
# 1     Thai    40   avg_rating    gender_tuned   5.000000     4.930769
# 2     Thai    40  num_ratings    gender_tuned   2.500000     8.153846
# 3   German    40        price    gender_tuned  29.636364    29.586207
# 4   German    40   avg_rating    gender_tuned   4.910000     4.962069
#
#    median_male  median_female count_male count_female  variance_male  \
# 0        13.00           13.0          4           36       1.687500
# 1         5.00            5.0          4           36       0.000000
# 2         1.50            5.0          4           36       4.250000
# 3        30.00           29.0         11           29     139.867769
# 4         4.95            5.0         11           29            NaN
#
#    variance_female  statistic   p_value Language  average_num_teachers
# 0        10.249228   0.416667  0.478608     Thai                 51.67
# 1              NaN   0.277778  0.890579     Thai                 51.67
# 2              NaN   0.527778  0.199584     Thai                 51.67
# 3        73.552913   0.134796  0.992602   German                388.67
# 4         0.007182   0.213166  0.771131   German                388.67

# %%
preply_results.to_csv('../data/results/features_analysis/gender/preply.csv', sep=',')

# %%
preply_results[preply_results['p_value']<0.1]
# Out:
#        language top_k   target_col aggregation_col  mean_male  mean_female  \
# 9        Hebrew    40        price    gender_tuned  24.578947    31.380952
# 10       Hebrew    40   avg_rating    gender_tuned   4.953846     4.826316
# 18      Persian    24        price    gender_tuned   8.785714    18.300000
# 23        Dutch    40  num_ratings    gender_tuned  21.555556     3.181818
# 56     Japanese    40  num_ratings    gender_tuned  20.083333     8.625000
# 68         Thai    58  num_ratings    gender_tuned   3.888889     8.342857
# 72   Portuguese   354        price    gender_tuned  10.673913    12.425926
# 75       Hebrew    59        price    gender_tuned  24.862069    31.966667
# 80        Hindi   119  num_ratings    gender_tuned  15.809524    16.244898
# 84      Persian    24        price    gender_tuned   8.785714    18.300000
# 89        Dutch    94  num_ratings    gender_tuned  14.631579     4.275862
# 103     English   591   avg_rating    gender_tuned   4.893064     4.922257
# 104     English   492  num_ratings    gender_tuned  20.046243    12.266458
# 105      Polish   122        price    gender_tuned  13.690476    15.850000
# 108      Arabic   420        price    gender_tuned   9.857843    11.083333
# 120    Japanese   352        price    gender_tuned  15.544643    15.725000
# 125     Spanish   465  num_ratings    gender_tuned  13.538462     8.570149
# 126      French   887        price    gender_tuned  15.729730    19.393502
#
#      median_male  median_female count_male count_female  variance_male  \
# 9           24.0           31.0         19           21      68.349030
# 10           5.0            4.9         19           21            NaN
# 18           8.0           17.0         14           10      18.311224
# 23           7.0            3.0         19           21            NaN
# 56          16.0            6.0         13           27            NaN
# 68           2.0            5.0          9           49      10.320988
# 72           8.0           13.0        138          216      36.654537
# 75          24.0           30.0         29           30      59.084423
# 80           6.0            9.0         45           74            NaN
# 84           8.0           17.0         14           10      18.311224
# 89           6.0            3.0         42           52            NaN
# 103          5.0            5.0        202          389            NaN
# 104         10.0            6.0        173          319     694.518093
# 105         12.0           15.0         42           80      19.118481
# 108          8.0           10.0        204          216      23.837635
# 120         13.0           14.0        112          240      89.640864
# 125          8.5            6.0        130          335     314.663905
# 126         14.0           17.0        333          554      50.161188
#
#      variance_female  statistic       p_value    Language  \
# 9         133.473923   0.413534  4.515880e-02      Hebrew
# 10               NaN   0.413534  4.515880e-02      Hebrew
# 18         22.810000   0.757143  9.871225e-04     Persian
# 23               NaN   0.370927  9.498668e-02       Dutch
# 56               NaN   0.470085  2.984851e-02    Japanese
# 68               NaN   0.448980  6.644773e-02        Thai
# 72         45.337106   0.189010  4.091501e-03  Portuguese
# 75        160.298889   0.328736  5.386391e-02      Hebrew
# 80               NaN   0.235135  7.448520e-02       Hindi
# 84         22.810000   0.757143  9.871225e-04     Persian
# 89               NaN   0.294872  2.694861e-02       Dutch
# 103              NaN   0.118596  4.278033e-02     English
# 104       346.471320   0.178629  1.307827e-03     English
# 105        68.527500   0.236310  7.539840e-02      Polish
# 108        29.206019   0.144336  2.219418e-02      Arabic
# 120        37.899375   0.176786  1.462688e-02    Japanese
# 125        81.367467   0.144776  3.495245e-02     Spanish
# 126        69.549127   0.209625  1.695652e-08      French
#
#      average_num_teachers
# 9                   46.67
# 10                  46.67
# 18                  54.33
# 23                  73.67
# 56                 410.33
# 68                  51.67
# 72                 462.67
# 75                  46.67
# 80                  78.00
# 84                  54.33
# 89                  73.67
# 103               5607.00
# 104               5607.00
# 105                 87.00
# 108                418.67
# 120                410.33
# 125               2348.33
# 126                832.33

# %% [markdown]
# # Italki

# %%
italki = pd.read_csv('../data/results/final_dataframes/italki.csv', index_col=0)
italki = italki.drop_duplicates(subset=['user_id', 'language'])

# %%
italki.head()

# %%
italki.columns
# Out:
# Index(['position', 'retrieval_date', 'user_id', 'user_name',
#        'avatar_file_name', 'video_picture', 'is_pro', 'nationality', 'teaches',
#        'also_speaks', 'in_platform_since', 'rating', 'number_sessions',
#        'price', 'price_time', 'price_currency', 'clean_name', 'sanitized_name',
#        'gender', 'probability', 'count', 'language', 'probability_male',
#        'probability_female', 'gender_tuned', 'income_level', 'Code'],
#       dtype='object')

# %%
italki_results_40 = compute_aggregated_feature_top_k(italki, 40, 'language', 'gender_tuned', ['price', 'rating', 'number_sessions'], 'male', 'female')

# %%
italki_results_all = compute_aggregated_feature_top_k(italki, None, 'language', 'gender_tuned', ['price', 'rating', 'number_sessions'], 'male', 'female')

# %%
italki_results = pd.concat([italki_results_40, italki_results_all])

# %%
italki_results = pd.merge(italki_results, average_number, how='left', left_on='language', right_on='Language')
italki_results = italki_results.rename(columns={'Average': 'average_num_teachers'})

# %%
italki_results.head()
# Out:
#   language top_k       target_col aggregation_col    mean_male  mean_female  \
# 0     Thai    40            price    gender_tuned   957.181818  1067.931034
# 1     Thai    40           rating    gender_tuned     4.972727     4.817241
# 2     Thai    40  number_sessions    gender_tuned   136.272727   408.896552
# 3   German    40            price    gender_tuned  2366.384615  2482.142857
# 4   German    40           rating    gender_tuned     4.792308     4.992857
#
#    median_male  median_female count_male count_female  variance_male  \
# 0        950.0         1000.0         11           29   1.011394e+05
# 1          5.0            5.0         11           29   1.983471e-03
# 2         73.0          160.0         11           29   2.620911e+04
# 3       1900.0         1650.0         26           14   1.960935e+06
# 4          5.0            5.0         26           14   9.199408e-01
#
#    variance_female  statistic   p_value Language  average_num_teachers
# 0     8.538193e+04   0.253918  0.589953     Thai                 51.67
# 1     8.303924e-01   0.169279  0.941853     Thai                 51.67
# 2     2.399008e+05   0.291536  0.415214     Thai                 51.67
# 3     2.481288e+06   0.104396  0.999390   German                388.67
# 4     6.632653e-04   0.120879  0.996088   German                388.67

# %%
italki_results.to_csv('../data/results/features_analysis/gender/italki.csv', sep=',')

# %%
italki_results[italki_results['p_value']<0.1]
# Out:
#                language top_k       target_col aggregation_col    mean_male  \
# 20   Chinese (Mandarin)    40  number_sessions    gender_tuned  1426.272727
# 32              Russian    40  number_sessions    gender_tuned  3031.666667
# 45              Turkish    40            price    gender_tuned   879.739130
# 63      Persian (Farsi)    40            price    gender_tuned   804.958333
# 72           Portuguese   352            price    gender_tuned  1114.641176
# 74           Portuguese   352  number_sessions    gender_tuned   596.029412
# 78                Hindi    95            price    gender_tuned   724.792453
# 87                Dutch    78            price    gender_tuned  1455.886364
# 96              Russian   400            price    gender_tuned   992.943820
# 108              Arabic   220            price    gender_tuned  1122.465649
# 109              Arabic   220           rating    gender_tuned     4.974046
# 111             Turkish   158            price    gender_tuned   919.195122
# 120             Spanish   400            price    gender_tuned  1196.696429
# 123              French   400            price    gender_tuned  1507.132653
# 129     Persian (Farsi)   102            price    gender_tuned   812.534884
#
#      mean_female  median_male  median_female count_male count_female  \
# 20    566.034483        442.0          205.0         11           29
# 32    686.029412       2408.5          371.5          6           34
# 45   1125.294118        800.0         1100.0         23           17
# 63   1143.687500        760.0         1000.0         24           16
# 72   1171.010989        950.0         1000.0        170          182
# 74    742.967033        261.5          319.5        170          182
# 78    868.452381        640.0          800.0         53           42
# 87   1866.470588       1345.0         1630.0         44           34
# 96   1162.035370        900.0         1000.0         89          311
# 108  1371.157303       1000.0         1000.0        131           89
# 109     4.957303          5.0            5.0        131           89
# 111  1076.447368        825.0         1000.0         82           76
# 120  1273.892241       1000.0         1100.0        168          232
# 123  1797.745098       1325.0         1700.0        196          204
# 129   962.271186        700.0          900.0         43           59
#
#      variance_male  variance_female  statistic       p_value    Language  \
# 20    3.994764e+06     1.316269e+06   0.554859  8.342761e-03         NaN
# 32    5.717581e+06     5.596662e+05   0.607843  2.559361e-02     Russian
# 45    1.402211e+05     9.576609e+04   0.460358  2.115657e-02     Turkish
# 63    8.082546e+04     2.628102e+05   0.416667  5.755151e-02         NaN
# 72    6.109428e+05     2.489128e+05   0.177440  6.617717e-03  Portuguese
# 74    1.350027e+06     1.163338e+06   0.149321  3.454602e-02  Portuguese
# 78    7.768926e+04     1.173860e+05   0.244834  9.761415e-02       Hindi
# 87    2.941040e+05     5.308640e+05   0.319519  3.001359e-02       Dutch
# 96    1.705057e+05     2.266118e+05   0.193649  9.303260e-03     Russian
# 108   5.413119e+05     9.640902e+05   0.174029  6.925793e-02      Arabic
# 109   3.601189e-03     3.120818e-03   0.171884  7.520115e-02      Arabic
# 111   1.838959e+05     1.610788e+05   0.247112  1.271690e-02     Turkish
# 120   3.431356e+05     3.110403e+05   0.124795  8.667562e-02     Spanish
# 123   4.662190e+05     5.223652e+05   0.270008  6.308508e-07      French
# 129   1.982522e+05     1.688041e+05   0.263303  5.088158e-02         NaN
#
#      average_num_teachers
# 20                    NaN
# 32                 560.33
# 45                 151.33
# 63                    NaN
# 72                 462.67
# 74                 462.67
# 78                  78.00
# 87                  73.67
# 96                 560.33
# 108                418.67
# 109                418.67
# 111                151.33
# 120               2348.33
# 123                832.33
# 129                   NaN

# %% [markdown]
# # Verbling

# %%
verbling = pd.read_csv('../data/results/final_dataframes/verbling.csv', index_col=0)
verbling = verbling.drop_duplicates(subset=['first_name', 'last_name', 'language'])

# %%
verbling.head()

# %%
verbling.columns
# Out:
# Index(['language', 'position', 'retrieval_date', 'is_featured', 'first_name',
#        'last_name', 'url', 'nationality', 'location', 'avg_rating',
#        'avg_lessons_per_students', 'num_ratings', 'teaching_levels', 'teaches',
#        'class_details', 'speaks', 'lessons', 'students', 'dialect',
#        'price_currency', 'avatar_url', 'clean_name', 'sanitized_name',
#        'gender', 'probability', 'count', 'price_detail', 'price',
#        'probability_male', 'probability_female', 'gender_tuned',
#        'income_level', 'Code'],
#       dtype='object')

# %%
verbling_results_40 = compute_aggregated_feature_top_k(verbling, 40, 'language', 'gender_tuned', ['price', 'avg_rating', 'num_ratings', 'avg_lessons_per_students'], 'male', 'female')

# %%
verbling_results_all = compute_aggregated_feature_top_k(verbling, None, 'language', 'gender_tuned', ['price', 'avg_rating', 'num_ratings', 'avg_lessons_per_students'], 'male', 'female')

# %%
verbling_results = pd.concat([verbling_results_40, verbling_results_all])

# %%
verbling_results = pd.merge(verbling_results, average_number, how='left', left_on='language', right_on='Language')
verbling_results = verbling_results.rename(columns={'Average': 'average_num_teachers'})

# %%
verbling_results.to_csv('../data/results/features_analysis/gender/verbling.csv', sep=',')

# %%
verbling_results
# Out:
#     language top_k                target_col aggregation_col   mean_male  \
# 0       Thai    18                     price    gender_tuned   17.333333
# 1       Thai    18                avg_rating    gender_tuned    4.990358
# 2       Thai    18               num_ratings    gender_tuned  107.666667
# 3       Thai    18  avg_lessons_per_students    gender_tuned   20.733333
# 4     German    40                     price    gender_tuned   30.436667
# ..       ...   ...                       ...             ...         ...
# 171   French   157  avg_lessons_per_students    gender_tuned   11.334375
# 172   Korean    46                     price    gender_tuned   22.428571
# 173   Korean    46                avg_rating    gender_tuned    3.876069
# 174   Korean    46               num_ratings    gender_tuned  148.428571
# 175   Korean    46  avg_lessons_per_students    gender_tuned    9.707143
#
#      mean_female  median_male  median_female count_male count_female  \
# 0      18.200000    17.000000      17.000000          3           15
# 1       4.326513     4.994152       5.000000          3           15
# 2      54.533333   143.000000       6.000000          3           15
# 3      13.500000    23.000000      11.100000          3           15
# 4      34.705263    30.000000      30.000000         21           19
# ..           ...          ...            ...        ...          ...
# 171    12.961290    10.950000      12.500000         64           93
# 172    24.743750    25.000000      23.500000         14           32
# 173     4.350986     4.944928       4.993081         14           32
# 174   230.562500    33.000000      59.500000         14           32
# 175    12.428125    10.350000      12.650000         14           32
#
#      variance_male  variance_female  statistic   p_value Language  Average
# 0         4.222222         8.560000   0.200000  1.000000     Thai    51.67
# 1         0.000096         2.880090   0.333333  0.921569     Thai    51.67
# 2      5786.888889      7176.915556   0.466667  0.571078     Thai    51.67
# 3        17.928889       116.926667   0.600000  0.272059     Thai    51.67
# 4        70.078679        67.768920   0.318296  0.210598   German   388.67
# ..             ...              ...        ...       ...      ...      ...
# 171      33.276943        44.922157   0.190020  0.110307   French   832.33
# 172      24.959184        41.535586   0.191964  0.790171   Korean   175.00
# 173       4.102226         2.708247   0.544643  0.003497   Korean   175.00
# 174   35658.530612    133054.683594   0.160714  0.918684   Korean   175.00
# 175      44.922092        69.949521   0.254464  0.468772   Korean   175.00
#
# [176 rows x 16 columns]

# %%
verbling_results[verbling_results['p_value']<0.1]
# Out:
#        language top_k   target_col aggregation_col  mean_male  mean_female  \
# 9        Hebrew    40        price    gender_tuned  24.578947    31.380952
# 10       Hebrew    40   avg_rating    gender_tuned   4.953846     4.826316
# 18      Persian    24        price    gender_tuned   8.785714    18.300000
# 23        Dutch    40  num_ratings    gender_tuned  21.555556     3.181818
# 56     Japanese    40  num_ratings    gender_tuned  20.083333     8.625000
# 68         Thai    58  num_ratings    gender_tuned   3.888889     8.342857
# 72   Portuguese   354        price    gender_tuned  10.673913    12.425926
# 75       Hebrew    59        price    gender_tuned  24.862069    31.966667
# 80        Hindi   119  num_ratings    gender_tuned  15.809524    16.244898
# 84      Persian    24        price    gender_tuned   8.785714    18.300000
# 89        Dutch    94  num_ratings    gender_tuned  14.631579     4.275862
# 103     English   591   avg_rating    gender_tuned   4.893064     4.922257
# 104     English   492  num_ratings    gender_tuned  20.046243    12.266458
# 105      Polish   122        price    gender_tuned  13.690476    15.850000
# 108      Arabic   420        price    gender_tuned   9.857843    11.083333
# 120    Japanese   352        price    gender_tuned  15.544643    15.725000
# 125     Spanish   465  num_ratings    gender_tuned  13.538462     8.570149
# 126      French   887        price    gender_tuned  15.729730    19.393502
#
#      median_male  median_female count_male count_female  variance_male  \
# 9           24.0           31.0         19           21      68.349030
# 10           5.0            4.9         19           21            NaN
# 18           8.0           17.0         14           10      18.311224
# 23           7.0            3.0         19           21            NaN
# 56          16.0            6.0         13           27            NaN
# 68           2.0            5.0          9           49      10.320988
# 72           8.0           13.0        138          216      36.654537
# 75          24.0           30.0         29           30      59.084423
# 80           6.0            9.0         45           74            NaN
# 84           8.0           17.0         14           10      18.311224
# 89           6.0            3.0         42           52            NaN
# 103          5.0            5.0        202          389            NaN
# 104         10.0            6.0        173          319     694.518093
# 105         12.0           15.0         42           80      19.118481
# 108          8.0           10.0        204          216      23.837635
# 120         13.0           14.0        112          240      89.640864
# 125          8.5            6.0        130          335     314.663905
# 126         14.0           17.0        333          554      50.161188
#
#      variance_female  statistic       p_value  Language_x  \
# 9         133.473923   0.413534  4.515880e-02      Hebrew
# 10               NaN   0.413534  4.515880e-02      Hebrew
# 18         22.810000   0.757143  9.871225e-04     Persian
# 23               NaN   0.370927  9.498668e-02       Dutch
# 56               NaN   0.470085  2.984851e-02    Japanese
# 68               NaN   0.448980  6.644773e-02        Thai
# 72         45.337106   0.189010  4.091501e-03  Portuguese
# 75        160.298889   0.328736  5.386391e-02      Hebrew
# 80               NaN   0.235135  7.448520e-02       Hindi
# 84         22.810000   0.757143  9.871225e-04     Persian
# 89               NaN   0.294872  2.694861e-02       Dutch
# 103              NaN   0.118596  4.278033e-02     English
# 104       346.471320   0.178629  1.307827e-03     English
# 105        68.527500   0.236310  7.539840e-02      Polish
# 108        29.206019   0.144336  2.219418e-02      Arabic
# 120        37.899375   0.176786  1.462688e-02    Japanese
# 125        81.367467   0.144776  3.495245e-02     Spanish
# 126        69.549127   0.209625  1.695652e-08      French
#
#      average_num_teachers  Language_y  Average
# 9                   46.67      Hebrew    46.67
# 10                  46.67      Hebrew    46.67
# 18                  54.33     Persian    54.33
# 23                  73.67       Dutch    73.67
# 56                 410.33    Japanese   410.33
# 68                  51.67        Thai    51.67
# 72                 462.67  Portuguese   462.67
# 75                  46.67      Hebrew    46.67
# 80                  78.00       Hindi    78.00
# 84                  54.33     Persian    54.33
# 89                  73.67       Dutch    73.67
# 103               5607.00     English  5607.00
# 104               5607.00     English  5607.00
# 105                 87.00      Polish    87.00
# 108                418.67      Arabic   418.67
# 120                410.33    Japanese   410.33
# 125               2348.33     Spanish  2348.33
# 126                832.33      French   832.33
